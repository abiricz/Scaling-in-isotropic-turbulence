# %% [markdown]
# # Analysis of Forced Isotropic Flow

# %%
% pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import pyJHTDB

# %%
b = np.zeros( 65, dtype=int )
for i in range(65):
    b[i] = i/64*(512**3)
    print(b[i])
# Out:
# 0
# 2097152
# 4194304
# 6291456
# 8388608
# 10485760
# 12582912
# 14680064
# 16777216
# 18874368
# 20971520
# 23068672
# 25165824
# 27262976
# 29360128
# 31457280
# 33554432
# 35651584
# 37748736
# 39845888
# 41943040
# 44040192
# 46137344
# 48234496
# 50331648
# 52428800
# 54525952
# 56623104
# 58720256
# 60817408
# 62914560
# 65011712
# 67108864
# 69206016
# 71303168
# 73400320
# 75497472
# 77594624
# 79691776
# 81788928
# 83886080
# 85983232
# 88080384
# 90177536
# 92274688
# 94371840
# 96468992
# 98566144
# 100663296
# 102760448
# 104857600
# 106954752
# 109051904
# 111149056
# 113246208
# 115343360
# 117440512
# 119537664
# 121634816
# 123731968
# 125829120
# 127926272
# 130023424
# 132120576
# 134217728

# %%
for i in range(64):
    print(b[i], b[i+1])
# Out:
# 0 2097152
# 2097152 4194304
# 4194304 6291456
# 6291456 8388608
# 8388608 10485760
# 10485760 12582912
# 12582912 14680064
# 14680064 16777216
# 16777216 18874368
# 18874368 20971520
# 20971520 23068672
# 23068672 25165824
# 25165824 27262976
# 27262976 29360128
# 29360128 31457280
# 31457280 33554432
# 33554432 35651584
# 35651584 37748736
# 37748736 39845888
# 39845888 41943040
# 41943040 44040192
# 44040192 46137344
# 46137344 48234496
# 48234496 50331648
# 50331648 52428800
# 52428800 54525952
# 54525952 56623104
# 56623104 58720256
# 58720256 60817408
# 60817408 62914560
# 62914560 65011712
# 65011712 67108864
# 67108864 69206016
# 69206016 71303168
# 71303168 73400320
# 73400320 75497472
# 75497472 77594624
# 77594624 79691776
# 79691776 81788928
# 81788928 83886080
# 83886080 85983232
# 85983232 88080384
# 88080384 90177536
# 90177536 92274688
# 92274688 94371840
# 94371840 96468992
# 96468992 98566144
# 98566144 100663296
# 100663296 102760448
# 102760448 104857600
# 104857600 106954752
# 106954752 109051904
# 109051904 111149056
# 111149056 113246208
# 113246208 115343360
# 115343360 117440512
# 117440512 119537664
# 119537664 121634816
# 121634816 123731968
# 123731968 125829120
# 125829120 127926272
# 127926272 130023424
# 130023424 132120576
# 132120576 134217728

# %%
134217728 / 64
# Out:
# 2097152.0

# %% [markdown]
# ### High-resolution snapshot

# %%
data = pyJHTDB.dbinfo.isotropic1024coarse
data
# Out:
# {'name': 'isotropic1024coarse',
#  'xnodes': array([0.0000000e+00, 6.1359233e-03, 1.2271847e-02, ..., 6.2647777e+00,
#         6.2709136e+00, 6.2770495e+00], dtype=float32),
#  'nx': 1024,
#  'lx': 6.283185307179586,
#  'dx': 0.006135923151542565,
#  'xperiodic': True,
#  'xuniform': True,
#  'ynodes': array([0.0000000e+00, 6.1359233e-03, 1.2271847e-02, ..., 6.2647777e+00,
#         6.2709136e+00, 6.2770495e+00], dtype=float32),
#  'ny': 1024,
#  'ly': 6.283185307179586,
#  'dy': 0.006135923151542565,
#  'yperiodic': True,
#  'yuniform': True,
#  'znodes': array([0.0000000e+00, 6.1359233e-03, 1.2271847e-02, ..., 6.2647777e+00,
#         6.2709136e+00, 6.2770495e+00], dtype=float32),
#  'nz': 1024,
#  'lz': 6.283185307179586,
#  'dz': 0.006135923151542565,
#  'zperiodic': True,
#  'zuniform': True,
#  'time': array([0.0000000e+00, 1.9999999e-03, 3.9999997e-03, ..., 1.0049999e+01,
#         1.0051999e+01, 1.0054000e+01], dtype=float32),
#  'diss': 0.0928,
#  'nu': 0.000185}

# %%
# nu = data['nu']

# %%
L = 512
xnodes = data['xnodes'][:L]
ynodes = data['ynodes'][:L]
znodes = data['znodes'][:L]

# %%
import itertools

# %%
# %%time
# getting all possible coordinate points
points = np.array(list(itertools.product(xnodes, ynodes, znodes ) ) )
# Out:
# CPU times: user 2min 31s, sys: 44.6 s, total: 3min 16s
# Wall time: 3min 12s

# %%
points.shape
# Out:
# (134217728, 3)

# %%
points[:5]
# Out:
# array([[0.        , 0.        , 0.        ],
#        [0.        , 0.        , 0.00613592],
#        [0.        , 0.        , 0.01227185],
#        [0.        , 0.        , 0.01840777],
#        [0.        , 0.        , 0.02454369]], dtype=float32)

# %%
points[::256][:5] #print with ny steps
# Out:
# array([[0.        , 0.        , 0.        ],
#        [0.        , 0.        , 1.5707964 ],
#        [0.        , 0.00613592, 0.        ],
#        [0.        , 0.00613592, 1.5707964 ],
#        [0.        , 0.01227185, 0.        ]], dtype=float32)

# %%
points[::256*256][:5]
# Out:
# array([[0.        , 0.        , 0.        ],
#        [0.        , 0.7853982 , 0.        ],
#        [0.        , 1.5707964 , 0.        ],
#        [0.        , 2.3561945 , 0.        ],
#        [0.00613592, 0.        , 0.        ]], dtype=float32)

# %% [markdown]
# ### Requesting velocity

# %%
# load shared library
lTDB = pyJHTDB.libJHTDB()

# initialize webservices
lTDB.initialize()

# add token
auth_token  = "hu.elte.caesar.abiricz-fe734327"
lTDB.add_token(auth_token)

N = points.shape
print('First few coordinates of {0} points where variables are requested:'.format(N))
for p in range(10):
    print('{0}: {1}'.format(p, points[p]))
# Out:
# First few coordinates of (134217728, 3) points where variables are requested:
# 0: [0. 0. 0.]
# 1: [0.         0.         0.00613592]
# 2: [0.         0.         0.01227185]
# 3: [0.         0.         0.01840777]
# 4: [0.         0.         0.02454369]
# 5: [0.         0.         0.03067962]
# 6: [0.         0.         0.03681554]
# 7: [0.         0.         0.04295146]
# 8: [0.         0.         0.04908739]
# 9: [0.         0.         0.05522331]

# %%
# %%time
for i in range(64)[25:]: # MODIFY HERE IF FAILURE OCCURS
    print('Requesting velocity at {0} points...'.format(N))
    vel_at_points = lTDB.getData( 0, points[ b[i]:b[i+1] ], 
                                 data_set = 'isotropic1024coarse', getFunction = 'Velocity' )
    for p in range(3):
        print(i, '. turn')
        print('{0}: {1}'.format(p, vel_at_points[p]))
    #constructing a DataFrame to join the corresponding data
    Data = pd.DataFrame( points[ b[i]:b[i+1] ], columns = ['x', 'y', 'z'] )
    Data['v_x'] = vel_at_points[:,0]
    Data['v_y'] = vel_at_points[:,1]
    Data['v_z'] = vel_at_points[:,2]
    
    FD4Lag4 = 44
    temporalInterp = 0

    print('Requesting velocity gradient at {0} points...'.format(N))
    vel_grad_at_points = lTDB.getData( 0, points[ b[i]:b[i+1] ], sinterp = FD4Lag4, 
                                      tinterp = temporalInterp, data_set ='isotropic1024coarse', 
                                      getFunction = 'getVelocityGradient')
    for p in range(3):
        print(i, '. turn')
        print('{0}: '.format(p) +
              'duxdx = {0:+e}, duxdy = {1:+e}, duxdz = {2:+e}\n   '.format(vel_grad_at_points[p][0], vel_grad_at_points[p][1], vel_grad_at_points[p][2]) +
              'duydx = {0:+e}, duydy = {1:+e}, duydz = {2:+e}\n   '.format(vel_grad_at_points[p][3], vel_grad_at_points[p][4], vel_grad_at_points[p][5]) +
              'duzdx = {0:+e}, duzdy = {1:+e}, duzdz = {2:+e}'.format(vel_grad_at_points[p][6], vel_grad_at_points[p][7], vel_grad_at_points[p][8]))
    
    #constructing a DataFrame to join the corresponding data
    Data['d_ux_dx'] = vel_grad_at_points[:,0]
    Data['d_ux_dy'] = vel_grad_at_points[:,1]
    Data['d_ux_dz'] = vel_grad_at_points[:,2]
    Data['d_uy_dx'] = vel_grad_at_points[:,3]
    Data['d_uy_dy'] = vel_grad_at_points[:,4]
    Data['d_uy_dz'] = vel_grad_at_points[:,5]
    Data['d_uz_dx'] = vel_grad_at_points[:,6]
    Data['d_uz_dy'] = vel_grad_at_points[:,7]
    Data['d_uz_dz'] = vel_grad_at_points[:,8]
    
    Data.to_csv( "~/workspace/Temporary/abiricz/scratch/Isoturb_box512_"+str(i)+".csv", index=False, header=False )
# Out:
# Requesting velocity at (134217728, 3) points...
# 25 . turn
# 0: [ 0.9052996 -0.2406579 -0.7347213]
# 25 . turn
# 1: [ 0.9066962  -0.25275964 -0.72218347]
# 25 . turn
# 2: [ 0.9039475 -0.264122  -0.7451576]
# Requesting velocity gradient at (134217728, 3) points...
# 25 . turn
# 0: duxdx = +4.415143e+00, duxdy = +2.733772e+00, duxdz = -3.906021e-01
#    duydx = -3.293556e-01, duydy = -7.733021e+00, duydz = -6.963921e-01
#    duzdx = -2.917552e-02, duzdy = -8.342728e+00, duzdz = +3.670952e+00
# 25 . turn
# 1: duxdx = +5.551190e+00, duxdy = +5.823669e-01, duxdz = +1.463184e-01
#    duydx = -2.799181e+00, duydy = -4.997108e+00, duydz = -2.410482e+00
#    duzdx = -1.918075e-01, duzdy = -1.406956e+01, duzdz = -4.680347e-01
# 25 . turn
# 2: duxdx = +6.014963e+00, duxdy = -3.403915e+00, duxdz = -1.298426e+00
#    duydx = -3.443258e+00, duydy = +1.258669e+00, duydz = -2.504959e-01
#    duzdx = -1.703180e+00, duzdy = -2.093524e+01, duzdz = -7.608333e+00
# Requesting velocity at (134217728, 3) points...
# 26 . turn
# 0: [ 1.2239206  -0.54246444 -0.8424784 ]
# 26 . turn
# 1: [ 1.1644644 -0.5240463 -0.8978341]
# 26 . turn
# 2: [ 1.1170623  -0.5020246  -0.95126545]
# Requesting velocity gradient at (134217728, 3) points...
# 26 . turn
# 0: duxdx = +2.093672e+00, duxdy = -5.638725e+00, duxdz = -7.730789e+00
#    duydx = -7.063412e+00, duydy = +6.287891e+00, duydz = +3.657532e-01
#    duzdx = +6.074641e-01, duzdy = +2.745056e-01, duzdz = -8.277596e+00
# 26 . turn
# 1: duxdx = +3.121913e+00, duxdy = -3.590897e+00, duxdz = -9.749304e+00
#    duydx = -5.764586e+00, duydy = +6.066452e+00, duydz = +3.709175e+00
#    duzdx = +4.497083e+00, duzdy = +4.001938e+00, duzdz = -9.213607e+00
# 26 . turn
# 2: duxdx = +2.841616e+00, duxdy = -9.030762e-01, duxdz = -3.846194e+00
#    duydx = -5.622491e+00, duydy = +5.156479e+00, duydz = +4.389730e+00
#    duzdx = +5.917052e+00, duzdy = +3.275841e+00, duzdz = -7.956966e+00
# Requesting velocity at (134217728, 3) points...
# 27 . turn
# 0: [ 1.164932  -0.5080774 -0.8952962]
# 27 . turn
# 1: [ 1.1954815  -0.4528584  -0.97983587]
# 27 . turn
# 2: [ 1.1600118 -0.3746671 -1.0551174]
# Requesting velocity gradient at (134217728, 3) points...
# 27 . turn
# 0: duxdx = +4.149472e+00, duxdy = -7.378578e+00, duxdz = +6.451393e+00
#    duydx = +5.044922e+00, duydy = +9.952545e+00, duydz = +7.873173e+00
#    duzdx = +9.361135e-01, duzdy = +9.514664e+00, duzdz = -1.361684e+01
# 27 . turn
# 1: duxdx = +3.401089e+00, duxdy = -5.067368e+00, duxdz = +5.284986e-01
#    duydx = +6.831006e+00, duydy = +1.013391e+01, duydz = +1.120951e+01
#    duzdx = -2.273747e+00, duzdy = +5.833481e+00, duzdz = -1.345659e+01
# 27 . turn
# 2: duxdx = +1.438562e-01, duxdy = -1.330147e+00, duxdz = -1.202190e+01
#    duydx = +6.057242e+00, duydy = +1.097158e+01, duydz = +1.211141e+01
#    duzdx = -4.880849e+00, duzdy = +3.588493e+00, duzdz = -1.099942e+01
# Requesting velocity at (134217728, 3) points...
# 28 . turn
# 0: [ 0.9392213  -0.51526535 -0.43532673]
# 28 . turn
# 1: [ 0.9250802  -0.51338387 -0.35302132]
# 28 . turn
# 2: [ 0.88506246 -0.50420415 -0.3093137 ]
# Requesting velocity gradient at (134217728, 3) points...
# 28 . turn
# 0: duxdx = -2.114018e+01, duxdy = -3.278297e+00, duxdz = +2.621536e-01
#    duydx = -3.431043e+00, duydy = +6.029068e+00, duydz = +4.834061e-01
#    duzdx = -6.288188e+00, duzdy = -2.641815e+00, duzdz = +1.527460e+01
# 28 . turn
# 1: duxdx = -1.787844e+01, duxdy = +9.224472e-01, duxdz = -4.659998e+00
#    duydx = +1.258739e+00, duydy = +7.842388e+00, duydz = +5.854645e-01
#    duzdx = -1.869387e+00, duzdy = -1.224056e+00, duzdz = +1.057022e+01
# 28 . turn
# 2: duxdx = -1.132148e+01, duxdy = +4.795959e+00, duxdz = -7.637141e+00
#    duydx = +3.448041e+00, duydy = +7.117359e+00, duydz = +2.790164e+00
#    duzdx = +4.730702e+00, duzdy = -3.056240e-01, duzdz = +4.015034e+00
# Requesting velocity at (134217728, 3) points...
# 29 . turn
# 0: [ 0.7462303 -0.7458073 -0.4986381]
# 29 . turn
# 1: [ 0.779472   -0.7217297  -0.50597477]
# 29 . turn
# 2: [ 0.69286984 -0.7133636  -0.53521043]
# Requesting velocity gradient at (134217728, 3) points...
# 29 . turn
# 0: duxdx = -3.429112e+00, duxdy = -5.733459e+00, duxdz = +1.778619e+01
#    duydx = +1.430379e+00, duydy = +1.867508e+00, duydz = +7.763367e-01
#    duzdx = -3.516462e+00, duzdy = +2.090073e-01, duzdz = +1.337029e+00
# 29 . turn
# 1: duxdx = +6.030650e+00, duxdy = -5.779953e-01, duxdz = -6.046385e+00
#    duydx = -1.240444e-01, duydy = -2.044006e+00, duydz = +3.539833e+00
#    duzdx = +3.285712e-02, duzdy = -2.650490e-01, duzdz = -3.547439e+00
# 29 . turn
# 2: duxdx = +9.401268e+00, duxdy = -1.503502e+00, duxdz = -1.756152e+01
#    duydx = +3.088650e+00, duydy = -4.852272e+00, duydz = -1.133756e+00
#    duzdx = +3.290129e+00, duzdy = -3.606941e+00, duzdz = -4.262724e+00
# Requesting velocity at (134217728, 3) points...
# 30 . turn
# 0: [ 0.6888503  -0.5971685  -0.56990385]
# 30 . turn
# 1: [ 0.72693753 -0.57431287 -0.5733348 ]
# 30 . turn
# 2: [ 0.7342042 -0.5621688 -0.5693405]
# Requesting velocity gradient at (134217728, 3) points...
# 30 . turn
# 0: duxdx = +2.505737e+00, duxdy = -6.740273e+00, duxdz = +9.177696e+00
#    duydx = -9.296186e-01, duydy = -1.547615e+00, duydz = +4.762074e+00
#    duzdx = +3.316346e-01, duzdy = +4.570084e-01, duzdz = -1.143463e+00
# 30 . turn
# 1: duxdx = +1.488345e+00, duxdy = -2.779800e+00, duxdz = +3.487425e+00
#    duydx = -3.934936e-01, duydy = -1.557705e+00, duydz = +2.672659e+00
#    duzdx = +1.170215e-01, duzdy = +1.012154e+00, duzdz = +5.742359e-02
# 30 . turn
# 2: duxdx = +8.700860e-01, duxdy = -8.979797e-03, duxdz = -4.980005e-01
#    duydx = +2.172247e-01, duydy = -2.368420e+00, duydz = +2.144620e+00
#    duzdx = -5.118138e-01, duzdy = +8.041573e-01, duzdz = +1.422053e+00
# Requesting velocity at (134217728, 3) points...
# 31 . turn
# 0: [ 0.7106233 -0.5520965 -0.6384401]
# 31 . turn
# 1: [ 0.7170511  -0.5461604  -0.63257587]
# 31 . turn
# 2: [ 0.7339312 -0.5375582 -0.6289248]
# Requesting velocity gradient at (134217728, 3) points...
# 31 . turn
# 0: duxdx = -1.455862e+00, duxdy = -6.486382e+00, duxdz = -1.246643e-02
#    duydx = -4.234225e-02, duydy = +4.880257e-01, duydz = +4.784889e-01
#    duzdx = +1.046258e+00, duzdy = +4.527786e+00, duzdz = +1.025440e+00
# 31 . turn
# 1: duxdx = -2.189616e+00, duxdy = -7.214920e+00, duxdz = +1.962739e+00
#    duydx = -4.421360e-01, duydy = +1.137703e+00, duydz = +1.173001e+00
#    duzdx = +1.113394e+00, duzdy = +3.801121e+00, duzdz = +7.905664e-01
# 31 . turn
# 2: duxdx = -2.550160e+00, duxdy = -8.247993e+00, duxdz = +3.566595e+00
#    duydx = -2.370219e-01, duydy = +1.881241e+00, duydz = +1.926489e+00
#    duzdx = +8.068105e-01, duzdy = +2.964127e+00, duzdz = +4.074634e-01
# Requesting velocity at (134217728, 3) points...
# 32 . turn
# 0: [ 0.69903183 -0.5956689  -0.4732059 ]
# 32 . turn
# 1: [ 0.7077267 -0.6127146 -0.4558987]
# 32 . turn
# 2: [ 0.7277713 -0.6252321 -0.4409548]
# Requesting velocity gradient at (134217728, 3) points...
# 32 . turn
# 0: duxdx = -1.512801e+00, duxdy = -6.498566e-01, duxdz = +1.492210e+00
#    duydx = +1.867551e+00, duydy = -1.706318e+00, duydz = -4.108837e+00
#    duzdx = +2.245564e+00, duzdy = -1.379013e-02, duzdz = +3.220379e+00
# 32 . turn
# 1: duxdx = -2.352550e+00, duxdy = -2.012207e+00, duxdz = +2.222176e+00
#    duydx = +1.384530e+00, duydy = -2.185326e-01, duydz = -2.316986e+00
#    duzdx = +3.489942e+00, duzdy = +5.923500e-01, duzdz = +2.623682e+00
# 32 . turn
# 2: duxdx = -1.882575e+00, duxdy = -3.491699e+00, duxdz = +4.021183e+00
#    duydx = +4.880227e-01, duydy = -1.327782e-01, duydz = -1.370058e+00
#    duzdx = +4.066771e+00, duzdy = +1.161259e+00, duzdz = +2.051934e+00
# Requesting velocity at (134217728, 3) points...
# 33 . turn
# 0: [ 0.8122232 -0.5303662 -0.4756681]
# 33 . turn
# 1: [ 0.89368016 -0.41113433 -0.42555112]
# 33 . turn
# 2: [ 0.9467688  -0.29757655 -0.40005955]
# Requesting velocity gradient at (134217728, 3) points...
# 33 . turn
# 0: duxdx = +4.838013e+00, duxdy = -1.486012e+01, duxdz = +1.294595e+01
#    duydx = -1.133213e+00, duydy = -1.276689e+01, duydz = +1.576373e+01
#    duzdx = +3.709902e-01, duzdy = -4.733986e+00, duzdz = +7.916649e+00
# 33 . turn
# 1: duxdx = +4.629275e+00, duxdy = -1.286613e+01, duxdz = +1.185314e+01
#    duydx = +1.795800e+00, duydy = -1.140990e+01, duydz = +2.030995e+01
#    duzdx = +3.188286e-01, duzdy = -4.995056e+00, duzdz = +6.681688e+00
# 33 . turn
# 2: duxdx = +3.082589e+00, duxdy = -5.278069e+00, duxdz = +4.702888e+00
#    duydx = +1.168912e+00, duydy = -4.626089e+00, duydz = +1.529251e+01
#    duzdx = -1.203535e+00, duzdy = -2.707191e+00, duzdz = +1.727131e+00
# Requesting velocity at (134217728, 3) points...
# 34 . turn
# 0: [ 0.9254978  -0.44329208 -0.47715357]
# 34 . turn
# 1: [ 0.9087258  -0.33977222 -0.46069354]
# 34 . turn
# 2: [ 0.87976813 -0.2715586  -0.42513278]
# Requesting velocity gradient at (134217728, 3) points...
# 34 . turn
# 0: duxdx = -5.257727e+00, duxdy = -4.557419e+00, duxdz = -2.573448e+00
#    duydx = +7.785674e+00, duydy = +4.994133e+00, duydz = +2.097597e+01
#    duzdx = -2.929244e+00, duzdy = -1.058524e+01, duzdz = +3.960495e-01
# 34 . turn
# 1: duxdx = -8.344100e+00, duxdy = -3.874908e+00, duxdz = -3.592131e+00
#    duydx = +2.901298e+00, duydy = +3.606735e+00, duydz = +1.382392e+01
#    duzdx = -2.216095e+00, duzdy = -1.055823e+01, duzdz = +4.575732e+00
# 34 . turn
# 2: duxdx = -8.837213e+00, duxdy = -9.567337e-01, duxdz = -5.739915e+00
#    duydx = -1.721370e-01, duydy = +2.556152e+00, duydz = +9.158647e+00
#    duzdx = -1.350116e+00, duzdy = -9.973587e+00, duzdz = +6.366417e+00
# Requesting velocity at (134217728, 3) points...
# 35 . turn
# 0: [ 0.7079709  -0.09517437 -0.368312  ]
# 35 . turn
# 1: [ 0.8288192  -0.0470992  -0.48594266]
# 35 . turn
# 2: [ 0.9745904   0.00440413 -0.6086104 ]
# Requesting velocity gradient at (134217728, 3) points...
# 35 . turn
# 0: duxdx = +8.051563e+00, duxdy = -9.052727e+00, duxdz = +1.243985e+01
#    duydx = +7.748815e+00, duydy = +6.640456e+00, duydz = +6.770260e+00
#    duzdx = -1.651863e+01, duzdy = +5.098984e+00, duzdz = -1.502892e+01
# 35 . turn
# 1: duxdx = +1.898969e+01, duxdy = -1.547265e+01, duxdz = +2.393634e+01
#    duydx = +1.040576e+01, duydy = +2.724101e+00, duydz = +8.148454e+00
#    duzdx = -2.072666e+01, duzdy = +7.187630e+00, duzdz = -2.140662e+01
# 35 . turn
# 2: duxdx = +1.885747e+01, duxdy = -1.383393e+01, duxdz = +1.898286e+01
#    duydx = +1.452427e+01, duydy = -3.732857e+00, duydz = +8.697528e+00
#    duzdx = -1.580240e+01, duzdy = +2.192471e+00, duzdz = -1.483030e+01
# Requesting velocity at (134217728, 3) points...
# 36 . turn
# 0: [ 1.1580423   0.21220127 -0.8301668 ]
# 36 . turn
# 1: [ 1.1516998   0.23910153 -0.87019026]
# 36 . turn
# 2: [ 1.1311871   0.261554   -0.89727366]
# Requesting velocity gradient at (134217728, 3) points...
# 36 . turn
# 0: duxdx = +4.268794e+00, duxdy = +3.539925e+00, duxdz = -9.937973e-01
#    duydx = -5.127419e+00, duydy = +3.763313e+00, duydz = +5.439587e+00
#    duzdx = -6.749766e-02, duzdy = +1.683197e-01, duzdz = -8.103867e+00
# 36 . turn
# 1: duxdx = +2.223360e+00, duxdy = +5.553993e+00, duxdz = -2.207994e+00
#    duydx = -3.734178e+00, duydy = +3.240503e+00, duydz = +3.797249e+00
#    duzdx = +1.195826e+00, duzdy = -6.311646e-01, duzdz = -5.361147e+00
# 36 . turn
# 2: duxdx = +1.413251e+00, duxdy = +6.575401e+00, duxdz = -3.761726e+00
#    duydx = -2.172636e+00, duydy = +2.194996e+00, duydz = +3.587341e+00
#    duzdx = +1.468362e+00, duzdy = -2.771759e-01, duzdz = -3.513576e+00
# Requesting velocity at (134217728, 3) points...
# 37 . turn
# 0: [ 1.2038665   0.02981758 -0.5937779 ]
# 37 . turn
# 1: [ 1.1564689   0.07352495 -0.5860652 ]
# 37 . turn
# 2: [ 1.0682883   0.10849601 -0.5685078 ]
# Requesting velocity gradient at (134217728, 3) points...
# 37 . turn
# 0: duxdx = -1.564835e+00, duxdy = +3.748070e+00, duxdz = -5.335022e+00
#    duydx = -2.808506e+00, duydy = +1.703363e+00, duydz = +7.654577e+00
#    duzdx = +3.072864e+00, duzdy = -2.945652e+00, duzdz = -1.105423e-01
# 37 . turn
# 1: duxdx = -3.061754e+00, duxdy = +9.320541e+00, duxdz = -1.117526e+01
#    duydx = -3.666127e+00, duydy = +7.820411e-01, duydz = +6.807440e+00
#    duzdx = +3.167553e+00, duzdy = -3.112709e+00, duzdz = +2.408071e+00
# 37 . turn
# 2: duxdx = -4.568660e+00, duxdy = +1.648042e+01, duxdz = -1.725936e+01
#    duydx = -5.876410e+00, duydy = +1.876263e+00, duydz = +3.486219e+00
#    duzdx = +2.859368e+00, duzdy = -2.296124e+00, duzdz = +2.673216e+00
# Requesting velocity at (134217728, 3) points...
# 38 . turn
# 0: [ 1.05033    -0.09759942 -0.6917789 ]
# 38 . turn
# 1: [ 1.0074185  -0.11646879 -0.71490836]
# 38 . turn
# 2: [ 0.9587205  -0.12804851 -0.73806155]
# Requesting velocity gradient at (134217728, 3) points...
# 38 . turn
# 0: duxdx = -7.781190e-01, duxdy = +3.652023e+00, duxdz = -7.043900e+00
#    duydx = -4.549393e+00, duydy = +3.776803e+00, duydz = -2.557530e+00
#    duzdx = -2.251048e+00, duzdy = -5.864029e-01, duzdz = -2.971863e+00
# 38 . turn
# 1: duxdx = +2.838272e-01, duxdy = +4.906555e+00, duxdz = -7.656408e+00
#    duydx = -3.333363e+00, duydy = +3.618880e+00, duydz = -2.718327e+00
#    duzdx = -1.491627e+00, duzdy = -2.022911e+00, duzdz = -3.996003e+00
# 38 . turn
# 2: duxdx = +5.697674e-01, duxdy = +6.298012e+00, duxdz = -7.688867e+00
#    duydx = -1.835893e+00, duydy = +2.437440e+00, duydz = -1.484056e+00
#    duzdx = +3.963463e-01, duzdy = -4.246956e+00, duzdz = -3.251506e+00
# Requesting velocity at (134217728, 3) points...
# 39 . turn
# 0: [ 0.98085    -0.27399588 -0.747805  ]
# 39 . turn
# 1: [ 0.9423021  -0.28198647 -0.7563098 ]
# 39 . turn
# 2: [ 0.8733297  -0.30070037 -0.7527073 ]
# Requesting velocity gradient at (134217728, 3) points...
# 39 . turn
# 0: duxdx = -3.768601e+00, duxdy = +1.541679e+00, duxdz = -4.483719e+00
#    duydx = -2.596743e+00, duydy = +5.882694e+00, duydz = -1.234087e+00
#    duzdx = -2.801436e+00, duzdy = -2.762115e+00, duzdz = -1.998383e+00
# 39 . turn
# 1: duxdx = -5.735548e+00, duxdy = +2.155937e+00, duxdz = -8.677290e+00
#    duydx = -3.866107e+00, duydy = +6.530209e+00, duydz = -2.065344e+00
#    duzdx = -1.356115e+00, duzdy = -2.292747e+00, duzdz = -4.067593e-01
# 39 . turn
# 2: duxdx = -8.222538e+00, duxdy = +4.018593e+00, duxdz = -1.385719e+01
#    duydx = -5.495335e+00, duydy = +7.012640e+00, duydz = -3.858862e+00
#    duzdx = +1.513805e-02, duzdy = -1.726051e+00, duzdz = +1.477387e+00
# Requesting velocity at (134217728, 3) points...
# 40 . turn
# 0: [ 0.7873826  -0.15090334 -0.7320809 ]
# 40 . turn
# 1: [ 0.78916216 -0.14240292 -0.71594006]
# 40 . turn
# 2: [ 0.78616834 -0.12858176 -0.7013875 ]
# Requesting velocity gradient at (134217728, 3) points...
# 40 . turn
# 0: duxdx = -4.445946e+00, duxdy = +3.798721e+00, duxdz = +1.566391e-01
#    duydx = +3.326337e+00, duydy = +1.981278e+00, duydz = +1.228674e+00
#    duzdx = -4.743626e-01, duzdy = +7.402191e-01, duzdz = +2.461319e+00
# 40 . turn
# 1: duxdx = -5.273498e+00, duxdy = +3.627411e+00, duxdz = -1.376905e-01
#    duydx = +3.470656e+00, duydy = +2.516850e+00, duydz = +1.791292e+00
#    duzdx = -4.832150e-01, duzdy = +7.004318e-01, duzdz = +2.671983e+00
# 40 . turn
# 2: duxdx = -4.449217e+00, duxdy = +3.458580e+00, duxdz = +1.894770e-02
#    duydx = +3.076616e+00, duydy = +2.488412e+00, duydz = +2.550470e+00
#    duzdx = -1.326503e-02, duzdy = +3.384705e-01, duzdz = +1.793470e+00
# Requesting velocity at (134217728, 3) points...
# 41 . turn
# 0: [ 0.79566216 -0.07949498 -0.658851  ]
# 41 . turn
# 1: [ 0.8048131  -0.06699857 -0.66991985]
# 41 . turn
# 2: [ 0.8049125  -0.06607386 -0.68571943]
# Requesting velocity gradient at (134217728, 3) points...
# 41 . turn
# 0: duxdx = +1.598770e+00, duxdy = -8.587646e-01, duxdz = +2.390282e+00
#    duydx = -2.927343e+00, duydy = +8.095217e-02, duydz = +2.076679e+00
#    duzdx = -9.511329e-01, duzdy = +4.221649e-01, duzdz = -1.604843e+00
# 41 . turn
# 1: duxdx = +2.841230e+00, duxdy = -7.344284e-01, duxdz = +8.170996e-01
#    duydx = -2.445033e+00, duydy = -5.304604e-01, duydz = +1.171165e+00
#    duzdx = -8.081018e-01, duzdy = +5.000534e-01, duzdz = -2.227277e+00
# 41 . turn
# 2: duxdx = +3.683815e+00, duxdy = -5.788345e-01, duxdz = -1.132359e+00
#    duydx = -1.712906e+00, duydy = -9.826574e-01, duydz = -2.726436e-01
#    duzdx = +1.919443e-02, duzdy = +8.944168e-01, duzdz = -2.680650e+00
# Requesting velocity at (134217728, 3) points...
# 42 . turn
# 0: [ 0.94466704 -0.13949862 -1.0007607 ]
# 42 . turn
# 1: [ 0.9580749  -0.1442498  -0.97727937]
# 42 . turn
# 2: [ 0.95225817 -0.14916053 -0.9572003 ]
# Requesting velocity gradient at (134217728, 3) points...
# 42 . turn
# 0: duxdx = +2.106255e+00, duxdy = -1.445862e+00, duxdz = +3.753235e+00
#    duydx = -1.902630e+00, duydy = -5.813334e+00, duydz = +1.692200e-02
#    duzdx = -1.270167e+01, duzdy = -3.909927e+00, duzdz = +3.698044e+00
# 42 . turn
# 1: duxdx = +1.677058e+00, duxdy = -1.157768e+00, duxdz = +6.426811e-01
#    duydx = -2.515677e+00, duydy = -5.699184e+00, duydz = -1.607935e+00
#    duzdx = -1.134337e+01, duzdy = -3.170502e+00, duzdz = +3.834423e+00
# 42 . turn
# 2: duxdx = +1.633627e-01, duxdy = -1.637207e+00, duxdz = -2.607561e+00
#    duydx = +3.981538e+00, duydy = -2.625711e+00, duydz = +2.212399e+00
#    duzdx = -1.162852e+01, duzdy = -2.596077e+00, duzdz = +2.076258e+00
# Requesting velocity at (134217728, 3) points...
# 43 . turn
# 0: [ 0.6210479   0.26555353 -1.2535634 ]
# 43 . turn
# 1: [ 0.6196016   0.28992534 -1.2503611 ]
# 43 . turn
# 2: [ 0.6197602   0.31330797 -1.2432072 ]
# Requesting velocity gradient at (134217728, 3) points...
# 43 . turn
# 0: duxdx = -7.252179e-02, duxdy = -5.150711e+00, duxdz = -6.924171e-01
#    duydx = +3.732224e+00, duydy = -9.508133e-03, duydz = +3.998255e+00
#    duzdx = -2.962833e+00, duzdy = -4.690697e+00, duzdz = +2.378082e-02
# 43 . turn
# 1: duxdx = +9.191424e-01, duxdy = -5.513184e+00, duxdz = -5.084610e-02
#    duydx = +4.180210e+00, duydy = -1.838806e+00, duydz = +3.952369e+00
#    duzdx = -3.111910e+00, duzdy = -4.975647e+00, duzdz = +8.585663e-01
# 43 . turn
# 2: duxdx = +1.562393e+00, duxdy = -6.344978e+00, duxdz = +1.298926e-01
#    duydx = +4.321607e+00, duydy = -3.109884e+00, duydz = +3.587915e+00
#    duzdx = -3.158771e+00, duzdy = -4.997742e+00, duzdz = +1.599060e+00
# Requesting velocity at (134217728, 3) points...
# 44 . turn
# 0: [ 0.82586855  0.26144788 -1.2180995 ]
# 44 . turn
# 1: [ 0.82416296  0.2646427  -1.221568  ]
# 44 . turn
# 2: [ 0.817565    0.26825738 -1.2221797 ]
# Requesting velocity gradient at (134217728, 3) points...
# 44 . turn
# 0: duxdx = +4.751155e+00, duxdy = +3.394547e-01, duxdz = -1.057968e-01
#    duydx = -5.113121e-01, duydy = -4.262459e+00, duydz = +2.612896e-01
#    duzdx = +2.529792e+00, duzdy = +5.779495e-01, duzdz = -7.039108e-01
# 44 . turn
# 1: duxdx = +5.053401e+00, duxdy = +8.744736e-01, duxdz = -6.214228e-01
#    duydx = +1.794032e-01, duydy = -4.764202e+00, duydz = +5.517938e-01
#    duzdx = +1.948751e+00, duzdy = +2.426758e-01, duzdz = -3.465328e-01
# 44 . turn
# 2: duxdx = +4.776158e+00, duxdy = +2.187218e+00, duxdz = -1.618410e+00
#    duydx = +8.709966e-02, duydy = -4.855356e+00, duydz = +6.619645e-01
#    duzdx = +1.598947e+00, duzdy = -1.498032e-01, duzdz = +1.446411e-01
# Requesting velocity at (134217728, 3) points...
# 45 . turn
# 0: [ 1.0660477   0.23083702 -1.0701171 ]
# 45 . turn
# 1: [ 1.0698506   0.27971536 -1.1084208 ]
# 45 . turn
# 2: [ 1.056068    0.34637177 -1.15219   ]
# Requesting velocity gradient at (134217728, 3) points...
# 45 . turn
# 0: duxdx = +7.724951e+00, duxdy = -3.828636e+00, duxdz = +1.585564e+00
#    duydx = +4.388846e+00, duydy = -2.395044e+00, duydz = +6.304388e+00
#    duzdx = +8.364031e+00, duzdy = -4.576904e+00, duzdz = -5.337791e+00
# 45 . turn
# 1: duxdx = +9.170523e+00, duxdy = -4.628609e+00, duxdz = -5.630150e-01
#    duydx = +8.609406e+00, duydy = -2.375528e+00, duydz = +9.550799e+00
#    duzdx = +6.912898e+00, duzdy = -3.090637e+00, duzdz = -7.048216e+00
# 45 . turn
# 2: duxdx = +8.301036e+00, duxdy = -3.910011e+00, duxdz = -4.411545e+00
#    duydx = +1.260018e+01, duydy = -2.448475e+00, duydz = +1.182880e+01
#    duzdx = +6.698512e+00, duzdy = -1.832481e+00, duzdz = -6.254026e+00
# Requesting velocity at (134217728, 3) points...
# 46 . turn
# 0: [ 0.89224124  0.21529663 -0.52364415]
# 46 . turn
# 1: [ 0.89104426  0.22707117 -0.43017355]
# 46 . turn
# 2: [ 0.8762952   0.26355278 -0.342761  ]
# Requesting velocity gradient at (134217728, 3) points...
# 46 . turn
# 0: duxdx = -1.565480e+01, duxdy = +5.226982e+00, duxdz = -1.219940e-01
#    duydx = -5.275837e+00, duydy = +7.384853e-01, duydz = +1.706905e-01
#    duzdx = -6.403266e+00, duzdy = -7.983093e+00, duzdz = +1.474419e+01
# 46 . turn
# 1: duxdx = -1.678991e+01, duxdy = +6.512428e+00, duxdz = -8.500433e-01
#    duydx = -1.455252e+01, duydy = +1.851925e+00, duydz = +4.158918e+00
#    duzdx = -1.127707e+01, duzdy = -6.720600e+00, duzdz = +1.503777e+01
# 46 . turn
# 2: duxdx = -1.748236e+01, duxdy = +7.579765e+00, duxdz = -4.303756e+00
#    duydx = -2.441455e+01, duydy = +4.252502e+00, duydz = +6.717007e+00
#    duzdx = -1.586795e+01, duzdy = -5.043446e+00, duzdz = +1.365187e+01
# Requesting velocity at (134217728, 3) points...
# 47 . turn
# 0: [ 0.67597365  0.85740197 -0.11218607]
# 47 . turn
# 1: [ 0.6763305   1.0324582  -0.10478377]
# 47 . turn
# 2: [ 0.67238283  1.1799033  -0.11542827]
# Requesting velocity gradient at (134217728, 3) points...
# 47 . turn
# 0: duxdx = +1.079602e+01, duxdy = -1.981848e+01, duxdz = +4.911118e-01
#    duydx = +4.366715e+01, duydy = -1.382952e+01, duydz = +2.850623e+01
#    duzdx = +8.786015e-01, duzdy = -1.194607e+01, duzdz = +2.919378e+00
# 47 . turn
# 1: duxdx = +1.176108e+01, duxdy = -1.844193e+01, duxdz = -1.219053e-01
#    duydx = +4.064231e+01, duydy = -1.161627e+01, duydz = +2.725364e+01
#    duzdx = -2.944379e+00, duzdy = -1.167946e+01, duzdz = -4.807123e-01
# 47 . turn
# 2: duxdx = +1.078157e+01, duxdy = -1.599538e+01, duxdz = -1.709738e+00
#    duydx = +2.931253e+01, duydy = -8.551018e+00, duydz = +1.943460e+01
#    duzdx = -4.607931e+00, duzdy = -1.068772e+01, duzdz = -2.572725e+00
# Requesting velocity at (134217728, 3) points...
# 48 . turn
# 0: [ 0.75857323  1.1469301  -0.11340439]
# 48 . turn
# 1: [ 0.7395253  1.1362273 -0.1124258]
# 48 . turn
# 2: [ 0.72450966  1.1319113  -0.11000383]
# Requesting velocity gradient at (134217728, 3) points...
# 48 . turn
# 0: duxdx = +1.054719e+00, duxdy = -9.118805e-01, duxdz = -3.381561e+00
#    duydx = -2.841748e+00, duydy = -1.166321e+00, duydz = -1.774292e+00
#    duzdx = +2.269423e-02, duzdy = -2.276716e-01, duzdz = +5.652523e-02
# 48 . turn
# 1: duxdx = +1.027561e+00, duxdy = -7.383652e-01, duxdz = -2.739855e+00
#    duydx = -2.840817e+00, duydy = -1.306770e+00, duydz = -1.287898e+00
#    duzdx = -4.297307e-01, duzdy = +5.014277e-01, duzdz = +2.948992e-01
# 48 . turn
# 2: duxdx = +1.331447e+00, duxdy = -1.777420e-01, duxdz = -2.397725e+00
#    duydx = -2.168450e+00, duydy = -1.625778e+00, duydz = -3.806655e-01
#    duzdx = -3.740371e-01, duzdy = +8.088179e-01, duzdz = +2.972830e-01
# Requesting velocity at (134217728, 3) points...
# 49 . turn
# 0: [ 0.78602076  1.0817091  -0.12860984]
# 49 . turn
# 1: [ 0.7697065   1.0812174  -0.13210297]
# 49 . turn
# 2: [ 0.7620995   1.0685492  -0.13054448]
# Requesting velocity gradient at (134217728, 3) points...
# 49 . turn
# 0: duxdx = +8.630841e-01, duxdy = +1.825989e+00, duxdz = -3.083351e+00
#    duydx = -1.187432e+00, duydy = +9.556580e-02, duydz = +1.167908e-01
#    duzdx = +1.887320e-01, duzdy = -1.479263e-01, duzdz = -9.046221e-01
# 49 . turn
# 1: duxdx = +6.074856e-01, duxdy = +1.950745e+00, duxdz = -1.996959e+00
#    duydx = -9.778058e-01, duydy = -4.141006e-01, duydz = -1.002211e+00
#    duzdx = +8.737756e-02, duzdy = +3.539610e-01, duzdz = -1.403160e-01
# 49 . turn
# 2: duxdx = +2.186429e-01, duxdy = +2.102699e+00, duxdz = -5.330306e-01
#    duydx = -1.130093e+00, duydy = -7.799988e-01, duydz = -2.597494e+00
#    duzdx = -4.257317e-01, duzdy = +7.180195e-01, duzdz = +5.757098e-01
# Requesting velocity at (134217728, 3) points...
# 50 . turn
# 0: [ 0.83715796  0.9865312  -0.1564636 ]
# 50 . turn
# 1: [ 0.82727265  0.9883302  -0.16025972]
# 50 . turn
# 2: [ 0.8167057   0.9892755  -0.16009152]
# Requesting velocity gradient at (134217728, 3) points...
# 50 . turn
# 0: duxdx = +8.980075e-01, duxdy = +2.240410e+00, duxdz = -1.577408e+00
#    duydx = -2.486746e+00, duydy = +3.467560e-02, duydz = +1.058884e-01
#    duzdx = -3.923862e-01, duzdy = -1.066373e+00, duzdz = -9.613104e-01
# 50 . turn
# 1: duxdx = +1.277437e+00, duxdy = +2.481537e+00, duxdz = -1.739583e+00
#    duydx = -2.502507e+00, duydy = -1.106339e+00, duydz = +3.192835e-01
#    duzdx = -2.898972e-01, duzdy = -6.519213e-01, duzdz = -2.820814e-01
# 50 . turn
# 2: duxdx = +1.470077e+00, duxdy = +2.891670e+00, duxdz = -1.392657e+00
#    duydx = -2.349692e+00, duydy = -1.885513e+00, duydz = -1.936443e-01
#    duzdx = -4.383835e-01, duzdy = -3.149691e-01, duzdz = +3.496310e-01
# Requesting velocity at (134217728, 3) points...
# 51 . turn
# 0: [ 0.85776645  0.9318972  -0.1523085 ]
# 51 . turn
# 1: [ 0.8524242   0.92778206 -0.15940395]
# 51 . turn
# 2: [ 0.8475452   0.9294807  -0.16467258]
# Requesting velocity gradient at (134217728, 3) points...
# 51 . turn
# 0: duxdx = +6.886370e-01, duxdy = +4.840851e-01, duxdz = -1.047409e+00
#    duydx = -7.424897e-01, duydy = +6.258926e-01, duydz = -1.232620e+00
#    duzdx = +4.292743e-02, duzdy = +2.414045e-01, duzdz = -1.216612e+00
# 51 . turn
# 1: duxdx = +8.838797e-01, duxdy = +9.886169e-02, duxdz = -8.009729e-01
#    duydx = -5.709416e-01, duydy = +2.702942e-01, duydz = -1.388788e-01
#    duzdx = +2.625177e-01, duzdy = -2.523794e-01, duzdz = -1.049947e+00
# 51 . turn
# 2: duxdx = +5.566324e-01, duxdy = -1.984100e-01, duxdz = -7.316425e-01
#    duydx = -5.886788e-01, duydy = +8.354187e-03, duydz = +5.066307e-01
#    duzdx = +3.219090e-01, duzdy = -6.496248e-01, duzdz = -5.394943e-01
# Requesting velocity at (134217728, 3) points...
# 52 . turn
# 0: [ 0.9197844   0.9319035  -0.13165069]
# 52 . turn
# 1: [ 0.9053871   0.9305352  -0.13452005]
# 52 . turn
# 2: [ 0.88995063  0.9299738  -0.13927028]
# Requesting velocity gradient at (134217728, 3) points...
# 52 . turn
# 0: duxdx = +1.282087e+00, duxdy = +1.092163e+00, duxdz = -1.814697e+00
#    duydx = +7.950327e-01, duydy = -1.073883e+00, duydz = -6.277466e-01
#    duzdx = +7.816579e-02, duzdy = -8.093681e-01, duzdz = -2.046556e-01
# 52 . turn
# 1: duxdx = +1.054191e+00, duxdy = +6.117859e-01, duxdz = -2.524871e+00
#    duydx = +6.157852e-01, duydy = -2.794189e-01, duydz = -2.045269e-01
#    duzdx = +2.940796e-01, duzdy = -1.035582e+00, duzdz = -7.020614e-01
# 52 . turn
# 2: duxdx = +5.921044e-01, duxdy = +5.815659e-01, duxdz = -2.354401e+00
#    duydx = +2.827693e-01, duydy = +2.704620e-02, duydz = +4.581881e-01
#    duzdx = +1.454455e-01, duzdy = -8.698549e-01, duzdz = -5.996616e-01
# Requesting velocity at (134217728, 3) points...
# 53 . turn
# 0: [ 0.9349239   0.9608582  -0.14518529]
# 53 . turn
# 1: [ 0.8995499   0.95669913 -0.14036542]
# 53 . turn
# 2: [ 0.8688748   0.96384865 -0.13467693]
# Requesting velocity gradient at (134217728, 3) points...
# 53 . turn
# 0: duxdx = -1.113989e+00, duxdy = -2.960571e+00, duxdz = -5.757057e+00
#    duydx = -5.089912e-02, duydy = +1.543503e-01, duydz = -7.949066e-01
#    duzdx = -3.567633e-01, duzdy = -1.272307e+00, duzdz = +9.670820e-01
# 53 . turn
# 1: duxdx = -1.327757e+00, duxdy = -2.669571e+00, duxdz = -5.520173e+00
#    duydx = +3.253161e-01, duydy = +6.083908e-01, duydz = +2.106047e-01
#    duzdx = -5.633264e-01, duzdy = -1.066514e+00, duzdz = +9.489973e-01
# 53 . turn
# 2: duxdx = -1.561355e+00, duxdy = -2.887016e+00, duxdz = -4.523026e+00
#    duydx = +1.131081e+00, duydy = +1.335999e+00, duydz = +1.206510e+00
#    duzdx = -9.484490e-02, duzdy = -8.221998e-01, duzdz = +1.599709e-01
# Requesting velocity at (134217728, 3) points...
# 54 . turn
# 0: [ 0.73913276  0.9936367  -0.11216691]
# 54 . turn
# 1: [ 0.6947778   1.013007   -0.05798635]
# 54 . turn
# 2: [ 0.6690219   1.0554111  -0.02743447]
# Requesting velocity gradient at (134217728, 3) points...
# 54 . turn
# 0: duxdx = -1.109316e+01, duxdy = -6.025291e+00, duxdz = -8.899300e+00
#    duydx = +3.842568e+00, duydy = +2.774025e+00, duydz = +1.872284e+00
#    duzdx = +5.676852e+00, duzdy = -1.305971e+00, duzdz = +8.444624e+00
# 54 . turn
# 1: duxdx = -9.399978e+00, duxdy = -9.208706e+00, duxdz = -5.598060e+00
#    duydx = +6.727153e+00, duydy = +1.816177e+00, duydz = +4.246790e+00
#    duzdx = +7.857021e+00, duzdy = +6.798983e-02, duzdz = +7.564513e+00
# 54 . turn
# 2: duxdx = -3.965706e+00, duxdy = -9.387722e+00, duxdz = -2.329516e+00
#    duydx = +1.183752e+01, duydy = +2.533974e+00, duydz = +1.186411e+01
#    duzdx = +4.625752e+00, duzdy = +1.289208e+00, duzdz = +1.653895e+00
# Requesting velocity at (134217728, 3) points...
# 55 . turn
# 0: [0.69082355 1.3672636  0.12789616]
# 55 . turn
# 1: [0.6916716  1.5415049  0.21134502]
# 55 . turn
# 2: [0.6507096  1.6050533  0.29666156]
# Requesting velocity gradient at (134217728, 3) points...
# 55 . turn
# 0: duxdx = +1.612204e+00, duxdy = +1.412354e-01, duxdz = +3.765385e+00
#    duydx = +1.629144e+00, duydy = -1.727593e+01, duydz = +3.340944e+01
#    duzdx = +8.662983e+00, duzdy = -3.871751e+00, duzdz = +1.497633e+01
# 55 . turn
# 1: duxdx = -5.717381e+00, duxdy = +2.249756e+00, duxdz = -3.090814e+00
#    duydx = -3.964939e+00, duydy = -8.717651e+00, duydz = +1.955170e+01
#    duzdx = +1.325708e+01, duzdy = -2.773540e+00, duzdz = +1.335026e+01
# 55 . turn
# 2: duxdx = -1.506858e+01, duxdy = -5.691032e-01, duxdz = -1.140308e+01
#    duydx = -6.847230e+00, duydy = -1.037308e+00, duydz = +5.174617e+00
#    duzdx = +2.231921e+01, duzdy = -2.927900e+00, duzdz = +1.555132e+01
# Requesting velocity at (134217728, 3) points...
# 56 . turn
# 0: [ 0.4176364   1.8519379  -0.16717708]
# 56 . turn
# 1: [ 0.40049896  1.8499081  -0.2711814 ]
# 56 . turn
# 2: [ 0.4188789   1.8026242  -0.32521346]
# Requesting velocity gradient at (134217728, 3) points...
# 56 . turn
# 0: duxdx = +1.398481e+01, duxdy = -8.986931e+00, duxdz = -2.685707e+00
#    duydx = +1.233838e+01, duydy = +7.987549e+00, duydz = -6.374023e+00
#    duzdx = +8.773539e-02, duzdy = -9.881458e-01, duzdz = -2.128638e+01
# 56 . turn
# 1: duxdx = +7.990304e+00, duxdy = -1.503499e+01, duxdz = -7.395334e-01
#    duydx = +1.866459e+01, duydy = +3.893875e+00, duydz = -3.667503e+00
#    duzdx = +6.838378e+00, duzdy = +1.119221e+00, duzdz = -1.310139e+01
# 56 . turn
# 2: duxdx = -1.609070e+00, duxdy = -1.623900e+01, duxdz = +7.507751e+00
#    duydx = +2.537671e+01, duydy = +6.847168e+00, duydz = -6.256061e+00
#    duzdx = +9.252788e+00, duzdy = +4.973909e+00, duzdz = -4.754032e+00
# Requesting velocity at (134217728, 3) points...
# 57 . turn
# 0: [ 0.6941676   1.7873867  -0.22269544]
# 57 . turn
# 1: [ 0.67344785  1.7451274  -0.26646692]
# 57 . turn
# 2: [ 0.64396226  1.6740916  -0.27991256]
# Requesting velocity gradient at (134217728, 3) points...
# 57 . turn
# 0: duxdx = +2.097089e+00, duxdy = -3.364639e-01, duxdz = -2.640900e+00
#    duydx = -2.852828e+00, duydy = +7.419983e+00, duydz = -4.012192e+00
#    duzdx = +9.492887e+00, duzdy = +1.733045e+01, duzdz = -9.300305e+00
# 57 . turn
# 1: duxdx = +3.164679e-01, duxdy = -3.373508e+00, duxdz = -4.542294e+00
#    duydx = -5.620177e+00, duydy = +4.373245e+00, duydz = -9.882139e+00
#    duzdx = +9.374271e+00, duzdy = +1.674770e+01, duzdz = -4.707641e+00
# 57 . turn
# 2: duxdx = -3.147330e-01, duxdy = -5.579239e+00, duxdz = -3.632696e+00
#    duydx = -7.486408e+00, duydy = +6.956787e-01, duydz = -1.111681e+01
#    duzdx = +8.097486e+00, duzdy = +1.463422e+01, duzdz = -1.988312e-01
# Requesting velocity at (134217728, 3) points...
# 58 . turn
# 0: [ 0.6857779   1.6215205  -0.29251328]
# 58 . turn
# 1: [ 0.7273427  1.5971892 -0.2892087]
# 58 . turn
# 2: [ 0.7539738   1.5651731  -0.24858512]
# Requesting velocity gradient at (134217728, 3) points...
# 58 . turn
# 0: duxdx = +5.778252e-01, duxdy = +2.733231e+00, duxdz = +5.818359e+00
#    duydx = -2.889251e+00, duydy = +5.026245e-01, duydz = -2.551636e+00
#    duzdx = +1.879715e-01, duzdy = -1.645529e+00, duzdz = -1.743437e+00
# 58 . turn
# 1: duxdx = +1.002808e+00, duxdy = +2.504684e+00, duxdz = +5.679500e+00
#    duydx = +2.277901e+00, duydy = -5.824295e+00, duydz = -5.167154e+00
#    duzdx = -9.109010e-01, duzdy = +3.491905e+00, duzdz = +3.790168e+00
# 58 . turn
# 2: duxdx = +2.038984e-01, duxdy = +2.749275e+00, duxdz = +5.057513e+00
#    duydx = +6.048645e+00, duydy = -9.086792e+00, duydz = -3.625576e+00
#    duzdx = -3.303976e+00, duzdy = +8.842594e+00, duzdz = +7.767629e+00
# Requesting velocity at (134217728, 3) points...
# 59 . turn
# 0: [ 0.7036714   1.3776076  -0.31990194]
# 59 . turn
# 1: [ 0.68191624  1.3354578  -0.30094275]
# 59 . turn
# 2: [ 0.65218115  1.3080436  -0.2854427 ]
# Requesting velocity gradient at (134217728, 3) points...
# 59 . turn
# 0: duxdx = +1.938872e+00, duxdy = -2.689964e+00, duxdz = -1.879814e+00
#    duydx = +2.793959e+00, duydy = -5.222916e+00, duydz = -7.237762e+00
#    duzdx = -1.926771e+00, duzdy = -3.067341e-01, duzdz = +3.385113e+00
# 59 . turn
# 1: duxdx = +1.846294e+00, duxdy = -3.947002e+00, duxdz = -4.519688e+00
#    duydx = +2.641230e+00, duydy = -4.457085e+00, duydz = -5.865576e+00
#    duzdx = -2.615902e+00, duzdy = +1.066971e-02, duzdz = +2.760912e+00
# 59 . turn
# 2: duxdx = +2.123279e-02, duxdy = -6.373741e+00, duxdz = -4.584245e+00
#    duydx = +2.982020e+00, duydy = -2.654823e+00, duydz = -3.049534e+00
#    duzdx = -3.184997e+00, duzdy = -1.380859e+00, duzdz = +2.531120e+00
# Requesting velocity at (134217728, 3) points...
# 60 . turn
# 0: [ 0.77301973  1.3307244  -0.4765177 ]
# 60 . turn
# 1: [ 0.7800809   1.3023087  -0.49436036]
# 60 . turn
# 2: [ 0.74969083  1.2927917  -0.5319937 ]
# Requesting velocity gradient at (134217728, 3) points...
# 60 . turn
# 0: duxdx = +2.264624e+00, duxdy = +6.026382e+00, duxdz = +3.350777e+00
#    duydx = -1.071228e+00, duydy = -1.178490e+00, duydz = -4.755768e+00
#    duzdx = -2.894012e+00, duzdy = -3.403751e+00, duzdz = -1.175953e+00
# 60 . turn
# 1: duxdx = +3.140496e+00, duxdy = -1.326447e-01, duxdz = -1.989095e+00
#    duydx = -4.756538e-01, duydy = +1.392036e+00, duydz = -2.810381e+00
#    duzdx = -4.184356e+00, duzdy = -6.573830e+00, duzdz = -4.620507e+00
# 60 . turn
# 2: duxdx = +3.005746e+00, duxdy = -4.758759e+00, duxdz = -7.025673e+00
#    duydx = +9.690195e-01, duydy = +4.147377e+00, duydz = -2.117039e+00
#    duzdx = -4.914968e+00, duzdy = -9.219227e+00, duzdz = -7.461569e+00
# Requesting velocity at (134217728, 3) points...
# 61 . turn
# 0: [ 0.8321918  1.4540793 -0.3622179]
# 61 . turn
# 1: [ 0.9142659   1.4244673  -0.36667734]
# 61 . turn
# 2: [ 0.9565602   1.4009247  -0.39375174]
# Requesting velocity gradient at (134217728, 3) points...
# 61 . turn
# 0: duxdx = +2.529460e+00, duxdy = +7.982887e+00, duxdz = +1.271922e+01
#    duydx = +1.329030e+00, duydy = -2.342148e+00, duydz = -5.459290e+00
#    duzdx = +4.731559e+00, duzdy = -2.095119e+00, duzdz = -2.935677e-01
# 61 . turn
# 1: duxdx = +1.666241e+00, duxdy = +7.563019e+00, duxdz = +1.151738e+01
#    duydx = +3.805900e-01, duydy = +1.426239e-01, duydz = -4.118288e+00
#    duzdx = +4.265351e+00, duzdy = -2.207909e+00, duzdz = -2.361952e+00
# 61 . turn
# 2: duxdx = +4.577079e+00, duxdy = -2.420082e+00, duxdz = -3.333888e-01
#    duydx = +7.662901e-02, duydy = +1.550720e+00, duydz = -4.294668e+00
#    duzdx = +5.111966e+00, duzdy = -3.527958e+00, duzdz = -5.983564e+00
# Requesting velocity at (134217728, 3) points...
# 62 . turn
# 0: [ 0.8954847   1.461138   -0.16472149]
# 62 . turn
# 1: [ 0.964656    1.4220295  -0.18781087]
# 62 . turn
# 2: [ 1.0742743   1.4026474  -0.21289255]
# Requesting velocity gradient at (134217728, 3) points...
# 62 . turn
# 0: duxdx = -1.618122e+00, duxdy = +4.587990e+00, duxdz = +1.141544e+01
#    duydx = -6.770344e-03, duydy = +4.863541e+00, duydz = -8.107101e+00
#    duzdx = +1.753490e+00, duzdy = +1.892183e+00, duzdz = -3.215421e+00
# 62 . turn
# 1: duxdx = -2.230797e+00, duxdy = +3.978165e+00, duxdz = +1.460718e+01
#    duydx = +7.474015e-01, duydy = +6.199875e+00, duydz = -4.750381e+00
#    duzdx = +2.936849e+00, duzdy = +1.532642e+00, duzdz = -3.632290e+00
# 62 . turn
# 2: duxdx = -3.935173e+00, duxdy = +5.534500e+00, duxdz = +1.927112e+01
#    duydx = +1.762249e+00, duydy = +9.006241e+00, duydz = -1.122177e+00
#    duzdx = +5.253514e+00, duzdy = +1.880636e+00, duzdz = -5.774655e+00
# Requesting velocity at (134217728, 3) points...
# 63 . turn
# 0: [ 0.879022    1.4303446  -0.27833676]
# 63 . turn
# 1: [ 0.90546536  1.427048   -0.31563044]
# 63 . turn
# 2: [ 0.9053165   1.4196652  -0.33772588]
# Requesting velocity gradient at (134217728, 3) points...
# 63 . turn
# 0: duxdx = +4.959884e+00, duxdy = +5.165169e+00, duxdz = +6.406525e+00
#    duydx = +4.394206e+00, duydy = +1.967651e+00, duydz = -1.522278e+00
#    duzdx = +5.450755e-02, duzdy = +6.678690e+00, duzdz = -6.778461e+00
# 63 . turn
# 1: duxdx = +3.145975e+00, duxdy = +7.531639e+00, duxdz = +2.427027e+00
#    duydx = +4.748586e+00, duydy = +1.907837e+00, duydz = -1.534710e-01
#    duzdx = +4.199215e+00, duzdy = +7.572145e+00, duzdz = -4.932017e+00
# 63 . turn
# 2: duxdx = +1.703733e-01, duxdy = +1.104007e+01, duxdz = -3.234577e+00
#    duydx = +7.305591e-01, duydy = +2.451599e+00, duydz = -3.323990e+00
#    duzdx = +8.689512e+00, duzdy = +8.787361e+00, duzdz = -2.471541e+00
# CPU times: user 1h 22min 40s, sys: 4min 13s, total: 1h 26min 53s
# Wall time: 5h 16min 27s
# Parser   : 150 ms

# %%
# Data.to_csv( 'Isoturb_coords_vels_box128.csv', index=False )

# %%
"""%%time
FD4Lag4 = 44
temporalInterp = 0

print('Requesting velocity gradient at {0} points...'.format(N))
vel_grad_at_points = lTDB.getData( 0, points[ b[i]:b[i+1] ], sinterp = FD4Lag4, tinterp = temporalInterp, data_set ='isotropic1024coarse', 
                                  getFunction = 'getVelocityGradient')

for p in range(3):
    print('{0}: '.format(p) +
          'duxdx = {0:+e}, duxdy = {1:+e}, duxdz = {2:+e}\n   '.format(vel_grad_at_points[p][0], vel_grad_at_points[p][1], vel_grad_at_points[p][2]) +
          'duydx = {0:+e}, duydy = {1:+e}, duydz = {2:+e}\n   '.format(vel_grad_at_points[p][3], vel_grad_at_points[p][4], vel_grad_at_points[p][5]) +
          'duzdx = {0:+e}, duzdy = {1:+e}, duzdz = {2:+e}'.format(vel_grad_at_points[p][6], vel_grad_at_points[p][7], vel_grad_at_points[p][8]))"""
# Out:
# "%%time\nFD4Lag4 = 44\ntemporalInterp = 0\n\nprint('Requesting velocity gradient at {0} points...'.format(N))\nvel_grad_at_points = lTDB.getData( 0, points[ b[i]:b[i+1] ], sinterp = FD4Lag4, tinterp = temporalInterp, data_set ='isotropic1024coarse', \n                                  getFunction = 'getVelocityGradient')\n\nfor p in range(3):\n    print('{0}: '.format(p) +\n          'duxdx = {0:+e}, duxdy = {1:+e}, duxdz = {2:+e}\n   '.format(vel_grad_at_points[p][0], vel_grad_at_points[p][1], vel_grad_at_points[p][2]) +\n          'duydx = {0:+e}, duydy = {1:+e}, duydz = {2:+e}\n   '.format(vel_grad_at_points[p][3], vel_grad_at_points[p][4], vel_grad_at_points[p][5]) +\n          'duzdx = {0:+e}, duzdy = {1:+e}, duzdz = {2:+e}'.format(vel_grad_at_points[p][6], vel_grad_at_points[p][7], vel_grad_at_points[p][8]))"

# %%
"""Data['d_ux_dx'] = vel_grad_at_points[:,0]
Data['d_ux_dy'] = vel_grad_at_points[:,1]
Data['d_ux_dz'] = vel_grad_at_points[:,2]
Data['d_uy_dx'] = vel_grad_at_points[:,3]
Data['d_uy_dy'] = vel_grad_at_points[:,4]
Data['d_uy_dz'] = vel_grad_at_points[:,5]
Data['d_uz_dx'] = vel_grad_at_points[:,6]
Data['d_uz_dy'] = vel_grad_at_points[:,7]
Data['d_uz_dz'] = vel_grad_at_points[:,8]
#Data.head()"""
# Out:
# "Data['d_ux_dx'] = vel_grad_at_points[:,0]\nData['d_ux_dy'] = vel_grad_at_points[:,1]\nData['d_ux_dz'] = vel_grad_at_points[:,2]\nData['d_uy_dx'] = vel_grad_at_points[:,3]\nData['d_uy_dy'] = vel_grad_at_points[:,4]\nData['d_uy_dz'] = vel_grad_at_points[:,5]\nData['d_uz_dx'] = vel_grad_at_points[:,6]\nData['d_uz_dy'] = vel_grad_at_points[:,7]\nData['d_uz_dz'] = vel_grad_at_points[:,8]\n#Data.head()"

# %%
i
# Out:
# 63

# %%
# Data.to_csv( "Isoturb_box128_"+str(i)+".csv", index=False )
